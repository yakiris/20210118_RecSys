# %% [markdown]
# # Тема: Гибридные системы

# %% [markdown]
# **В качестве домашнего задания Вам необходимо ответить на вопросы:**
#
# 1. В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной фильтрации?
#     * гибридные рекомендательные системы обучаются с использованием дополнительных параметров.
#
#
# 2. Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы
#     * в случае холодного старта новый покупатель или новый товар
#     * в случае сильно разреженной user_item матрицы
#
#
# 3. Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/. Нам интересна именно рекомендательная система, раздел "Производительность системы" можно пропустить.
#     3.1. Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах?
#     * мы на семинарах не разбирали систему последовательной множественной фильтрации
#
#     3.2. Какие проблемы могут возникнуть при выводе такой модели в продакшен?
#     * т.к. перебор производится ночью, то в рекомендации попадают вакансии с задержкой.
#
#
# 4. На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
#     4.1. Какой датасет используют авторы?
#     * используется 2 наборах данных - MovieLens в сочетании с набором тегов Tag Genome tag set. Набор данных MovieLens состоит примерно из 10 миллионов рейтингов фильмов, представленных 71 567 пользователями по 10 681 фильму.
#
#     4.2. Что используют в качестве признаков?
#     * Все фильмы описываются по их жанрам и списку тегов из Tag Genome tag set. Каждая пара фильм-тег сопровождается оценкой релевантности (от 0 до 1), обозначающей, насколько точно данный тег описывает фильм.
#
#     4.3. С какими моделями сравнивают LightFM? Опишите их основные идеи кратко
#     * MF: модель колаборативной фильтрации (на матрице интеракций user - items)
#     * LSI-LR: модель контентной рекомендательной системы (на дополнительных параметрах)
#     * LSI-UP: гибридная модель (на матрице интеракций user - items с использванием дополнительных параметров)
